# %%
#The data verification shows us that they are complete.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp


df = pd.read_excel('AQM Project - Data.xlsx',sheet_name='EUR-USD', parse_dates = True, index_col = 'Date')
df.head()
# Out:
#             EUR-USD    CPI  Indus. Production  Unemployment  Retail sales  \
# Date
# 2013-01-31   1.3578  0.020             -0.004         0.119         0.009
# 2013-02-28   1.3056  0.019              0.005         0.120        -0.014
# 2013-03-31   1.2818  0.017              0.010         0.121        -0.024
# 2013-04-30   1.3166  0.012              0.003         0.122        -0.011
# 2013-05-31   1.2995  0.014             -0.003         0.121        -0.001
#
#             Trade Balance (in billions)  GBY 10 years    PPI
# Date
# 2013-01-31                         -3.9      0.023930  0.019
# 2013-02-28                         10.4      0.028582  0.013
# 2013-03-31                         22.9      0.030276  0.007
# 2013-04-30                         14.9      0.028552 -0.002
# 2013-05-31                         15.2      0.026856 -0.001

# %%
df.plot(subplots = True)
# Out:
# array([<AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>],
#       dtype=object)

# %%
df = pd.read_excel('AQM Project - Data.xlsx',sheet_name='GBP-USD', parse_dates = True, index_col = 'Date')
df.head()
# Out:
#             GBP-USD    CPI  Indus. Production  Unemployment  Retail sales  \
# Date
# 2013-01-31   1.5854  0.027             -0.030         0.079        -0.004
# 2013-02-28   1.5160  0.028             -0.022         0.078         0.019
# 2013-03-31   1.5201  0.028             -0.013         0.078        -0.016
# 2013-04-30   1.5531  0.024             -0.006         0.078         0.002
# 2013-05-31   1.5198  0.027             -0.023         0.078         0.010
#
#             Trade Balance (in billions)  GBY 15 years    PPI
# Date
# 2013-01-31                    -7.771755      0.033165  0.020
# 2013-02-28                    -7.793671      0.033493  0.023
# 2013-03-31                    -5.421444      0.034199  0.020
# 2013-04-30                    -5.059226      0.032366  0.011
# 2013-05-31                     2.270117      0.033481  0.012

# %%
df.plot(subplots = True)
# Out:
# array([<AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>],
#       dtype=object)

# %%
df = pd.read_excel('AQM Project - Data.xlsx',sheet_name='USD-CAD', parse_dates = True, index_col = 'Date')
df.head()
# Out:
#             USD-CAD    CPI  Indus. Production  Unemployment  Retail sales  \
# Date
# 2013-01-31   0.9969  0.005          -0.021364         0.071      0.014412
# 2013-02-28   1.0303  0.012           0.011019         0.070      0.023475
# 2013-03-31   1.0172  0.010           0.015519         0.073      0.018037
# 2013-04-30   1.0071  0.004          -0.000501         0.072      0.022535
# 2013-05-31   1.0375  0.007          -0.002036         0.070      0.041326
#
#             Trade Balance (in billions)  GBY 10 years    PPI
# Date
# 2013-01-31                    -0.055156        0.0247 -0.002
# 2013-02-28                    -0.012681        0.0239  0.010
# 2013-03-31                    -0.457257        0.0234  0.009
# 2013-04-30                    -0.116063        0.0219  0.000
# 2013-05-31                     0.928273        0.0248  0.000

# %%
df.plot(subplots = True)
# Out:
# array([<AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>],
#       dtype=object)

# %%
df = pd.read_excel('AQM Project - Data.xlsx',sheet_name='USD-JPY', parse_dates = True, index_col = 'Date')
df.head()
# Out:
#             USD-JPY    CPI  Indus. Production  Unemployment  Retail sales  \
# Date
# 2013-01-31    91.72 -0.003           -0.08228         0.042        -0.011
# 2013-02-28    92.53 -0.007           -0.06402         0.043        -0.023
# 2013-03-31    94.19 -0.009           -0.05053         0.041        -0.003
# 2013-04-30    97.41 -0.007           -0.04590         0.041        -0.001
# 2013-05-31   100.46 -0.003           -0.01292         0.041         0.008
#
#             Trade Balance (in billions)  GBY 10 years       PPI
# Date
# 2013-01-31                    -5.866579        0.0074 -0.000354
# 2013-02-28                   -10.336109        0.0067  0.001107
# 2013-03-31                   -11.400778        0.0056 -0.004007
# 2013-04-30                   -11.430565        0.0060  0.001995
# 2013-05-31                    -8.208418        0.0086  0.005996

# %%
df.plot(subplots = True)
# Out:
# array([<AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>],
#       dtype=object)

# %%
df = pd.read_excel('AQM Project - Data.xlsx',sheet_name='AUD-USD', parse_dates = True, index_col = 'Date')
df.head()
# Out:
#             AUD-USD       CPI  Indus. Production  Unemployment  Retail sales  \
# Date
# 2013-01-31   1.0422  0.023038           0.024220         0.054      0.036912
# 2013-02-28   1.0212  0.024032           0.020910         0.054      0.045531
# 2013-03-31   1.0417  0.025025           0.025031         0.056      0.029275
# 2013-04-30   1.0369  0.024650           0.029158         0.056      0.028111
# 2013-05-31   0.9570  0.024277           0.033292         0.056      0.025661
#
#             Trade Balance (in billions)  GBY 10 years       PPI
# Date
# 2013-01-31                    -0.702473      0.033975  0.014089
# 2013-02-28                    -0.277298      0.034975  0.016357
# 2013-03-31                     0.772090      0.035125  0.014925
# 2013-04-30                     0.454582      0.032450  0.013479
# 2013-05-31                     0.913674      0.032250  0.012019

# %%
df.plot(subplots = True)
# Out:
# array([<AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>],
#       dtype=object)

# %%
df = pd.read_excel('AQM Project - Data.xlsx',sheet_name='NZD-USD', parse_dates = True, index_col = 'Date')
df.head()
# Out:
#             NZD-USD       CPI  Balance of payments  Unemployment  \
# Date
# 2013-01-31   0.8387  0.009617             0.011006     -0.000458
# 2013-02-28   0.8244  0.009482            -0.028052     -0.047650
# 2013-03-31   0.8372  0.009357            -0.022322     -0.091082
# 2013-04-30   0.8549  0.008362             0.020420     -0.080191
# 2013-05-31   0.7934  0.007208             0.049232     -0.068673
#
#             Retail sales  Trade Balance (in billions)  GBY 10 years       PPI
# Date
# 2013-01-31      0.032510                    -0.164939        0.0355 -0.001596
# 2013-02-28      0.032510                     0.024317        0.0381  0.000000
# 2013-03-31      0.032510                    -0.047262        0.0372  0.000000
# 2013-04-30      0.032781                    -0.132183        0.0333  0.000000
# 2013-05-31      0.032781                    -0.184487        0.0337  0.000000

# %%
df.plot(subplots = True)
# Out:
# array([<AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>],
#       dtype=object)

# %%
df = pd.read_excel('AQM Project - Data.xlsx',sheet_name='USD-CHF', parse_dates = True, index_col = 'Date')
df.head()
# Out:
#             USD-CHF    CPI  Indus. Production  Unemployment  Retail sales  \
# Date
# 2013-01-31   0.9097 -0.003           0.011281         0.031         0.019
# 2013-02-28   0.9361 -0.002           0.011255         0.031         0.024
# 2013-03-31   0.9491 -0.006           0.009663         0.031        -0.009
# 2013-04-30   0.9291 -0.006           0.008003         0.031         0.033
# 2013-05-31   0.9549 -0.005           0.006275         0.032         0.018
#
#             Trade Balance (in billions)  GBY 10 years       PPI
# Date
# 2013-01-31                     2.889403       0.00789  0.012407
# 2013-02-28                     2.962290       0.00721  0.004398
# 2013-03-31                     0.596052       0.00747  0.002864
# 2013-04-30                     8.222515       0.00612  0.006522
# 2013-05-31                     2.213520       0.00760  0.002825

# %%
df.plot(subplots = True)
# Out:
# array([<AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>],
#       dtype=object)
